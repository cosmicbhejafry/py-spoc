# %%
from pyspoc import Calculator, Config
from pathlib import Path
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
# Out:
# Starting JVM with java class /Users/joshparchure/Documents/pyspocClone24Jun/py-spoc/pyspoc/lib/jidt/infodynamics.jar.
# Jpype JVM not available: [Errno 2] JVM DLL not found: /Library/Internet Plug-Ins/JavaAppletPlugin.plugin/Contents/Home

# %%
project_root = Path('./').resolve().parents[3]
print(project_root)
bin_ratio_path = os.path.join(project_root,'mastersResearch_Jun_Sept2025','causalDiscovery_J','ReducedStatistics','p_value_bin_ratios.py')
print(bin_ratio_path)
# Out:
# /Users/joshparchure/pyspocClone5Aug/py-spoc/working_analyses
# /Users/joshparchure/pyspocClone5Aug/py-spoc/working_analyses/mastersResearch_Jun_Sept2025/causalDiscovery_J/ReducedStatistics/p_value_bin_ratios.py

# %%
bin_ratio_config_yaml = f"""
ReducedStatistics:
  {bin_ratio_path}:
    pValueBinRatios:
        schemes:
            scheme_1:
                alpha: 0.05
                ratio_type: strong_to_moderate
"""
bin_ratio_config_name = "bin_ratios"
cfg = Config.from_yaml(bin_ratio_config_name, bin_ratio_config_yaml)
# Out:
# Registering YAML string.
# Building internal configuration.
# /Users/joshparchure/pyspocClone5Aug/py-spoc/working_analyses/mastersResearch_Jun_Sept2025/causalDiscovery_J/ReducedStatistics/p_value_bin_ratios.py
#     ✔ ReducedStatistic pValueBinRatios scheme 'scheme_1' added successfully.

# %%
base_dir = os.path.join(project_root, 'mastersResearch_Jun_Sept2025', 'causalDiscovery_J')

motivation_dag_1 = os.path.join(base_dir,'motivationAnalysis', 'motivation_dag_1.csv')
motivation_dag_1_df = pd.read_csv(motivation_dag_1)

dag1dataset1 = os.path.join(base_dir, 'dataGen', 'chain100data', 'dag1dataset1.csv')
dag1dataset1_df = pd.read_csv(dag1dataset1)

dag2dataset1 = os.path.join(base_dir, 'dataGen', 'loop100data', 'dag2dataset1.csv')
dag2dataset1_df = pd.read_csv(dag2dataset1)

# %%
calc = Calculator(motivation_dag_1_df)
calc.compute(cfg)
results = calc.results
print(results)

calc = Calculator(dag1dataset1_df)
calc.compute(cfg)
results = calc.results
print(results)

calc = Calculator(dag2dataset1_df)
calc.compute(cfg)
results = calc.results
print(results)
# Out:
# Normalising the dataset...
# Processing [None: /Users/joshparchure/pyspocClone5Aug/py-spoc/working_analyses/mastersResearch_Jun_Sept2025/causalDiscovery_J/ReducedStatistics/p_value_bin_ratios.py.pValueBinRatios.scheme_1]:   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# Processing [None: /Users/joshparchure/pyspocClone5Aug/py-spoc/working_analyses/mastersResearch_Jun_Sept2025/causalDiscovery_J/ReducedStatistics/p_value_bin_ratios.py.pValueBinRatios.scheme_1]: 100%|██████████| 1/1 [00:00<00:00, 44.26it/s]
# Calculation complete. Time taken: 0.0247s
# Statistic /Users/joshparchure/pyspocClone5Aug/py-spoc/working_analyses/mastersResearch_Jun_Sept2025/causalDiscovery_J/ReducedStatistics/p_value_bin_ratios.py.pValueBinRatios.scheme_1
# Reducer                                                                                                                                                                           self
# ...

# %%
data_dir1 = os.path.join(base_dir, 'dataGen', 'chain100data')

# Get a list of all items in the directory
all_items = os.listdir(data_dir1)

# Filter for files that are CSVs and create their full paths
csv_files = []
for item in all_items:
    if item.endswith('.csv'):
        file_path = os.path.join(data_dir1, item)
        csv_files.append(file_path)

# Select the first 5 files
files_to_process = csv_files[:5]

# Process each of the selected files
for file_path in files_to_process:
    print(f"Processing file: {os.path.basename(file_path)}")
    
    # Read the CSV file
    df = pd.read_csv(file_path)

    # Initialize and run the Calculator
    calc = Calculator(df)
    calc.compute(cfg)
    results = calc.results
    
    # Print the results
    print(results)
    print("---")
# Out:
# Processing file: dag1dataset37.csv
# Normalising the dataset...
# Processing [None: /Users/joshparchure/pyspocClone5Aug/py-spoc/working_analyses/mastersResearch_Jun_Sept2025/causalDiscovery_J/ReducedStatistics/p_value_bin_ratios.py.pValueBinRatios.scheme_1]:   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Processing [None: /Users/joshparchure/pyspocClone5Aug/py-spoc/working_analyses/mastersResearch_Jun_Sept2025/causalDiscovery_J/ReducedStatistics/p_value_bin_ratios.py.pValueBinRatios.scheme_1]: 100%|██████████| 1/1 [00:08<00:00,  8.22s/it]
# Calculation complete. Time taken: 8.2242s
# Statistic /Users/joshparchure/pyspocClone5Aug/py-spoc/working_analyses/mastersResearch_Jun_Sept2025/causalDiscovery_J/ReducedStatistics/p_value_bin_ratios.py.pValueBinRatios.scheme_1
# Reducer                                                                                                                                                                           self
# ...

# %%
data_dir2 = os.path.join(base_dir, 'dataGen', 'loop100data')

# Get a list of all items in the directory
all_items = os.listdir(data_dir2)

# Filter for files that are CSVs and create their full paths
csv_files = []
for item in all_items:
    if item.endswith('.csv'):
        file_path = os.path.join(data_dir2, item)
        csv_files.append(file_path)

# Select the first 5 files
files_to_process = csv_files[:5]

# Process each of the selected files
for file_path in files_to_process:
    print(f"Processing file: {os.path.basename(file_path)}")
    
    # Read the CSV file
    df = pd.read_csv(file_path)

    # Initialize and run the Calculator
    calc = Calculator(df)
    calc.compute(cfg)
    results = calc.results
    
    # Print the results
    print(results)
    print("---")
# Out:
# Processing file: dag2dataset17.csv
# Normalising the dataset...
# Processing [None: /Users/joshparchure/pyspocClone5Aug/py-spoc/working_analyses/mastersResearch_Jun_Sept2025/causalDiscovery_J/ReducedStatistics/p_value_bin_ratios.py.pValueBinRatios.scheme_1]:   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Processing [None: /Users/joshparchure/pyspocClone5Aug/py-spoc/working_analyses/mastersResearch_Jun_Sept2025/causalDiscovery_J/ReducedStatistics/p_value_bin_ratios.py.pValueBinRatios.scheme_1]: 100%|██████████| 1/1 [00:05<00:00,  5.88s/it]
# Calculation complete. Time taken: 5.8772s
# Statistic /Users/joshparchure/pyspocClone5Aug/py-spoc/working_analyses/mastersResearch_Jun_Sept2025/causalDiscovery_J/ReducedStatistics/p_value_bin_ratios.py.pValueBinRatios.scheme_1
# Reducer                                                                                                                                                                           self
# ...
