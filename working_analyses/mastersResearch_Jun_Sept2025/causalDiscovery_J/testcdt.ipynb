# %%
import numpy as np
import pandas as pd
from cdt.causality.graph import PC
import networkx as nx
import matplotlib.pyplot as plt
# Out:
# No GPU automatically detected. Setting SETTINGS.GPU to 0, and SETTINGS.NJOBS to cpu_count.

# %%
data = {
    'temperature': np.random.uniform(15, 35, 100),
    'humidity': np.random.uniform(40, 90, 100),
    'wind_speed': np.random.uniform(5, 25, 100),
    'pressure': np.random.uniform(980, 1030, 100),
}
df = pd.DataFrame(data)
display(df)
# Out:
#     temperature   humidity  wind_speed     pressure
# 0     32.578032  63.840076   12.797812   988.930049
# 1     20.160267  51.820429    5.309168   990.067563
# 2     20.770384  64.421960   15.523938  1023.311222
# 3     15.749460  65.620359   20.373296  1010.290838
# 4     15.234956  73.497627   17.344325   995.995408
# ..          ...        ...         ...          ...
# 95    22.887750  63.483836   21.588226  1023.776916
# 96    25.002591  61.013710   12.516609   994.615829
# 97    28.987551  71.188174   15.020943  1006.680873
# 98    16.325279  73.044624   12.960565   989.434522
# 99    15.374375  71.954506    5.794661   997.367552
#
# [100 rows x 4 columns]

# %%
pc_alg = PC()
graph = pc_alg.predict(df)
print(graph)
nx.draw_networkx(graph, with_labels=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pc_alg = PC()
#       2 graph = pc_alg.predict(df)
#       3 print(graph)
#
# File /opt/anaconda3/envs/pyspoc_env/lib/python3.12/site-packages/cdt/causality/graph/PC.py:176, in PC.__init__(self, CItest, method_indep, alpha, njobs, verbose)
#     174 """Init the model and its available arguments."""
#     175 if not (RPackages.pcalg and RPackages.kpcalg and RPackages.RCIT):
# --> 176     raise ImportError("R Package (k)pcalg/RCIT is not available. "
#     177                       "RCIT has to be installed from "
#     178                       "https://github.com/Diviyan-Kalainathan/RCIT")
#     180 super(PC, self).__init__()
#     181 self.dir_CI_test = {'binary': "pcalg::binCItest", # ic.method=\"dcc\"",
#     182                          'discrete': "pcalg::disCItest",
#     183                          'hsic_gamma': "kpcalg::kernelCItest",
#    (...)    187                          'rcit': "RCIT:::CItest",
#     188                          'rcot': "RCIT:::CItest"}
#
# ImportError: R Package (k)pcalg/RCIT is not available. RCIT has to be installed from https://github.com/Diviyan-Kalainathan/RCIT
