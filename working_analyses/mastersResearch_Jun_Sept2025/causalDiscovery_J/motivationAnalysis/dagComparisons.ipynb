# %%
from pyspoc import Calculator, Config
# Out:
# Starting JVM with java class /Users/joshparchure/Documents/pyspocClone24Jun/py-spoc/pyspoc/lib/jidt/infodynamics.jar.
# Jpype JVM not available: [Errno 2] JVM DLL not found: /Library/Internet Plug-Ins/JavaAppletPlugin.plugin/Contents/Home

# %%
from pathlib import Path
import os
import numpy as np
import pandas as pd
# Add the parent of the current script's parent to sys.path
project_root = Path('./').resolve().parents[2]

# %%
new_mod_path = os.path.join(project_root,'hjResearch_2025','summary_stats','distance_distrib_stats.py')

# %%
my_config_yaml = f"""
ReducedStatistic:
  {new_mod_path}:
    DistanceDistributionBase:
        schemes:
          scheme_1:
            stats: 
              - euclidean

DistanceDistributionBase:
  {new_mod_path}:
    DistanceDistributionModesSummarize:
        schemes:
          scheme_1:
            stats: 
              - euclidean
"""

my_config_name = "new_config"
cfg = Config.from_yaml(my_config_name, my_config_yaml)
# Out:
# Registering YAML string.
# Building internal configuration.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 20
#       1 my_config_yaml = f"""
#       2 ReducedStatistic:
#       3   {new_mod_path}:
#    (...)     16               - euclidean
#      17 """
#      19 my_config_name = "new_config"
# ---> 20 cfg = Config.from_yaml(my_config_name, my_config_yaml)
#
# File ~/Documents/pyspocClone24Jun/py-spoc/pyspoc/config.py:120, in Config.from_yaml(cls, name, yaml_string)
#     118 print("Registering YAML string.")
#     119 instance.__config_dict = yaml.load(yaml_string, Loader=yaml.FullLoader)
# --> 120 instance.__process_config_file()
#     121 return instance
#
# File ~/Documents/pyspocClone24Jun/py-spoc/pyspoc/config.py:623, in Config.__process_config_file(self)
#     617 invalid_config = all(
#     618     [not stats_spec and not reducers_spec,
#     619      not rstats_spec]
#     620 )
#     622 if invalid_config:
# --> 623     raise ValueError(f"Configuration is missing required definitions. One of the following must be fulfilled:"
#     624                     "   - At least one Statistic and one Reducer specified."
#     625                     "   - At least one ReducedStatistic specified.")
#     627 self.__build_config_scheme(stats_spec, reducers_spec, rstats_spec)
#
# ValueError: Configuration is missing required definitions. One of the following must be fulfilled:   - At least one Statistic and one Reducer specified.   - At least one ReducedStatistic specified.

# %%
filename_dict = {}

for dataset_type in ['motivation_dag_1', 'motivation_dag_2']:

    n_sample = 1000
    n_feature = 3
    base_dir = os.path.join(project_root,'mastersResearch_Jun_Sept2025','causalDiscovery_J','motivationAnalysis',dataset_type,f'N{n_sample}_P{n_feature}')
    # subfolder_path = os.path.join(base_dir,'k3_std1.0')
    subfolder_path = base_dir

    meta_file = os.path.join(subfolder_path, "meta.csv")
    meta_df = pd.read_csv(meta_file)

    ## change this to take sample_num from meta_df:
    filename_dict[dataset_type] = {v.split('_')[0] : os.path.join(subfolder_path,v) for v in meta_df['filename']}
